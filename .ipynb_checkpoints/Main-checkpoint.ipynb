# %%
from ucimlrepo import fetch_ucirepo 
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %%
heart_disease = fetch_ucirepo(id=45) 
  
    
X = heart_disease.data.features 
y = heart_disease.data.targets

# %%
print(X.info())
X.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        299 non-null    float64
#  12  thal      301 non-null    float64
# dtypes: float64(3), int64(10)
# memory usage: 30.9 KB
# None
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#     ca  thal
# 0  0.0   6.0
# 1  3.0   3.0
# 2  2.0   7.0
# 3  0.0   3.0
# 4  0.0   3.0

# %%
print(y.info())
y.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   num     303 non-null    int64
# dtypes: int64(1)
# memory usage: 2.5 KB
# None
#    num
# 0    0
# 1    2
# 2    1
# 3    0
# 4    0

# %%
print("Feature dataset dimensions (X):", X.shape)
print("Target dataset dimensions (y):", y.shape)
# Out:
# Feature dataset dimensions (X): (303, 13)
# Target dataset dimensions (y): (303, 1)

# %%
print("Target unique values:", y['num'].unique())
# Out:
# Target unique values: [0 2 1 3 4]

# %%
print("Summary statistics:")
print(X.describe())
# Out:
# Summary statistics:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769  246.693069    0.148515
# std      9.038662    0.467299    0.960126   17.599748   51.776918    0.356198
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# std      0.994971   22.875003    0.469794    1.161075    0.616226    0.937438
# min      0.000000   71.000000    0.000000    0.000000    1.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    2.000000    0.000000
# 75%      2.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    3.000000    3.000000
#
#              thal
# count  301.000000
# mean     4.734219
# std      1.939706
# min      3.000000
# 25%      3.000000
# 50%      3.000000
# 75%      7.000000
# max      7.000000

# %%
print("Target label distribution:")
print(y['num'].value_counts())
# Out:
# Target label distribution:
# 0    164
# 1     55
# 2     36
# 3     35
# 4     13
# Name: num, dtype: int64

# %%
X.hist(figsize=(12, 10), bins=20)
plt.suptitle("Feature Distributions")
plt.show()

# %%
print("Missing values Features:")
print(X.isnull().sum())

print("\nMissing values Target:")
print(y.isnull().sum())
# Out:
# Missing values Features:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# dtype: int64
#
# Missing values Target:
# num    0
# dtype: int64

# %%
print(X.ca.unique())
print(X.thal.unique())
# Out:
# [ 0.  3.  2.  1. nan]
# [ 6.  3.  7. nan]

# %%
X = X.copy()  # Create a deep copy of the DataFrame
X['ca'] = X['ca'].fillna(X['ca'].mode()[0])
X['thal'] = X['thal'].fillna(X['thal'].mode()[0])

# %%
X.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#     ca  thal
# 0  0.0   6.0
# 1  3.0   3.0
# 2  2.0   7.0
# 3  0.0   3.0
# 4  0.0   3.0

# %%
X = pd.get_dummies(X, columns=['cp', 'restecg', 'ca', 'thal'], drop_first=True)

# %%
scaler = StandardScaler()
X[['age', 'trestbps', 'chol', 'thalach', 'oldpeak']] = scaler.fit_transform(X[['age', 'trestbps', 'chol', 'thalach', 'oldpeak']])

# %%
print(X.describe())
# Out:
#                 age         sex      trestbps          chol         fbs  \
# count  3.030000e+02  303.000000  3.030000e+02  3.030000e+02  303.000000
# mean  -1.465641e-18    0.679868  4.426236e-16  2.345026e-16    0.148515
# std    1.001654e+00    0.467299  1.001654e+00  1.001654e+00    0.356198
# min   -2.819115e+00    0.000000 -2.145037e+00 -2.334877e+00    0.000000
# 25%   -7.135564e-01    0.000000 -6.652997e-01 -6.905030e-01    0.000000
# 50%    1.729945e-01    1.000000 -9.616980e-02 -1.101357e-01    0.000000
# 75%    7.270888e-01    1.000000  4.729601e-01  5.476139e-01    0.000000
# max    2.500191e+00    1.000000  3.887739e+00  6.138485e+00    1.000000
#
#             thalach       exang       oldpeak       slope        cp_2  \
# count  3.030000e+02  303.000000  3.030000e+02  303.000000  303.000000
# mean  -1.172513e-16    0.326733  2.345026e-17    1.600660    0.165017
# cp_4       0.464293  0.274218  0.209528 -0.423065 -0.599104  1.000000
# restecg_1  0.042729  0.168172  0.122080 -0.051418 -0.008678  0.063635
# restecg_2  0.079445  0.094202  0.119150 -0.096449 -0.087962  0.114539
# ca_1.0     0.150206 -0.011613 -0.000561 -0.059046  0.027661  0.050053
# ca_2.0     0.097399  0.218319  0.035229 -0.087804 -0.194184  0.218318
# ca_3.0     0.013188  0.189296  0.107744 -0.082372 -0.019946  0.119643
# thal_6.0   0.063073  0.104635  0.185825 -0.036496 -0.096275  0.096330
# thal_7.0   0.300223  0.302145  0.217318 -0.188225 -0.168515  0.304008
#
#            restecg_1  restecg_2    ca_1.0    ca_2.0    ca_3.0  thal_6.0  \
# age         0.084097   0.138313  0.175941  0.224533  0.160884  0.062042
# sex        -0.106574   0.033676  0.100103 -0.017836  0.068455  0.142524
# trestbps    0.057995   0.139000 -0.061240  0.086654  0.078830  0.075157
# chol        0.033691   0.166100  0.014457  0.056806  0.096464 -0.095743
# fbs        -0.048305   0.074634 -0.014774  0.122080  0.075867  0.091351
# thalach    -0.120829  -0.069061 -0.194853 -0.056323 -0.175277 -0.159523
# exang       0.042729   0.079445  0.150206  0.097399  0.013188  0.063073
# oldpeak     0.168172   0.094202 -0.011613  0.218319  0.189296  0.104635
# slope       0.122080   0.119150 -0.000561  0.035229  0.107744  0.185825
# cp_2       -0.051418  -0.096449 -0.059046 -0.087804 -0.082372 -0.036496
# cp_3       -0.008678  -0.087962  0.027661 -0.194184 -0.019946 -0.096275
# cp_4        0.063635   0.114539  0.050053  0.218318  0.119643  0.096330
# restecg_1   1.000000  -0.113021  0.009997 -0.043799  0.085710  0.093258
# restecg_2  -0.113021   1.000000  0.052287  0.048622  0.085917  0.033738
# ca_1.0      0.009997   0.052287  1.000000 -0.197896 -0.138928  0.004715
# ca_2.0     -0.043799   0.048622 -0.197896  1.000000 -0.100668  0.073462
# ca_3.0      0.085710   0.085917 -0.138928 -0.100668  1.000000  0.045653
# thal_6.0    0.093258   0.033738  0.004715  0.073462  0.045653  1.000000
# thal_7.0   -0.032342   0.011547  0.113962  0.109028  0.116774 -0.199320
#
#            thal_7.0
# age        0.104902
# sex        0.326284
# trestbps   0.106210
# chol       0.053100
# fbs        0.030953
# thalach   -0.214326
# exang      0.300223
# oldpeak    0.302145
# slope      0.217318
# cp_2      -0.188225
# cp_3      -0.168515
# cp_4       0.304008
# restecg_1 -0.032342
# restecg_2  0.011547
# ca_1.0     0.113962
# ca_2.0     0.109028
# ca_3.0     0.116774
# thal_6.0  -0.199320
# thal_7.0   1.000000

# %%
numerical_cols = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']
X[numerical_cols].hist(bins=15, figsize=(10, 6))
plt.tight_layout()
plt.show()

# %%
for col in numerical_cols:
    plt.figure(figsize=(6, 4))
    plt.boxplot(X[col])
    plt.title(f'Box Plot of {col}')
    plt.show()

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
sns.pairplot(X[['age', 'chol', 'trestbps', 'thalach', 'oldpeak']])
plt.show()

# %%
for col in categorical_cols + numerical_cols:
    sns.boxplot(x=y['num'], y=X[col])
    plt.title(f'{col} vs num')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13508\261639485.py in <module>
#       1 for col in categorical_cols + numerical_cols:
# ----> 2     sns.boxplot(x=y['num'], y=X[col])
#       3     plt.title(f'{col} vs num')
#       4     plt.show()
#
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'cp'
